# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7.333333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Parser\n\nHere's a solution to extract the bucket name from an S3 URI:\n\n```python\ndef get_bucket_name(s3_uri: str) -> str:\n    \"\"\"\n    Extract the bucket name from an S3 URI.\n    \n    Args:\n        s3_uri: S3 URI in format s3://bucket-name/path/to/file\n        \n    Returns:\n        The bucket name\n        \n    Raises:\n        ValueError: If the URI is not a valid S3 URI\n    \"\"\"\n    if not s3_uri.startswith('s3://'):\n        raise ValueError(f\"Invalid S3 URI: {s3_uri}. Must start with 's3://'\")\n    \n    # Remove 's3://' prefix and split by '/'\n    path = s3_uri[5:]  # Remove 's3://'\n    bucket_name = path.split('/')[0]\n    \n    if not bucket_name:\n        raise ValueError(f\"Invalid S3 URI: {s3_uri}. No bucket name found\")\n    \n    return bucket_name\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        \"s3://my-bucket/path/to/file.txt\",\n        \"s3://simple-bucket/\",\n        \"s3://bucket-with-many-levels/deep/nested/path/file.pdf\",\n        \"s3://another-bucket\",\n    ]\n    \n    for uri in test_cases:\n        try:\n            bucket = get_bucket_name(uri)\n            print(f\"URI: {uri}\")\n            print(f\"Bucket: {bucket}\\n\")\n        except ValueError as e:\n            print(f\"Error: {e}\\n\")\n```\n\n**Output:**\n```\nURI: s3://my-bucket/path/to/file.txt\nBucket: my-bucket\n\nURI: s3://simple-bucket/\nBucket: simple-bucket\n\nURI: s3://bucket-with-many-levels/deep/nested/path/file.pdf\nBucket: bucket-with-many-levels\n\nURI: s3://another-bucket\nBucket: another-bucket\n```\n\n## Alternative: Using Regex\n\n```python\nimport re\n\ndef get_bucket_name_regex(s3_uri: str) -> str:\n    \"\"\"Extract bucket name using regex.\"\"\"\n    match = re.match(r's3://([a-z0-9\\-\\.]+)(?:/|$)', s3_uri)\n    if not match:\n        raise ValueError(f\"Invalid S3 URI: {s3_uri}\")\n    return match.group(1)\n```\n\n## Alternative: Using urllib\n\n```python\nfrom urllib.parse import urlparse\n\ndef get_bucket_name_urllib(s3_uri: str) -> str:\n    \"\"\"Extract bucket name using urllib.\"\"\"\n    parsed = urlparse(s3_uri)\n    if parsed.scheme != 's3':\n        raise ValueError(f\"Invalid S3 URI: {s3_uri}\")\n    return parsed.netloc\n```\n\n**Choose based on your needs:**\n- **Simple split()**: Best for basic use cases, most readable\n- **Regex**: Best if you need to validate bucket name format\n- **urllib**: Best if you're already using it for other URI parsing",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI (e.g., s3://my-bucket/path/to/file.txt) and extract just the bucket name",
#       "format": "regex"
#     },
#     "score": 7,
#     "reasoning": "The solution effectively solves the core task with multiple well-explained alternatives and good code quality. However, it lacks compliance with actual AWS S3 naming conventions and has a critical flaw in the regex pattern that would reject valid uppercase bucket names. The simple split() approach is practical for most cases but doesn't validate bucket name format. The solution would benefit from incorporating proper AWS bucket naming validation or at least documenting these limitations."
#   },
#   {
#     "output": "# AWS Lambda Function Configuration (JSON)\n\n```json\n{\n  \"FunctionName\": \"my-lambda-function\",\n  \"Runtime\": \"python3.11\",\n  \"Role\": \"arn:aws:iam::ACCOUNT_ID:role/lambda-execution-role\",\n  \"Handler\": \"index.lambda_handler\",\n  \"Timeout\": 30,\n  \"MemorySize\": 256,\n  \"Description\": \"Lambda function with Python 3.11 runtime\",\n  \"Environment\": {\n    \"Variables\": {}\n  },\n  \"Tags\": {\n    \"Environment\": \"production\",\n    \"Application\": \"my-app\"\n  }\n}\n```\n\n## Key Configuration Parameters:\n\n| Parameter | Value | Description |\n|-----------|-------|-------------|\n| **Runtime** | `python3.11` | Specifies Python 3.11 as the runtime environment |\n| **Timeout** | `30` | Maximum execution time in seconds |\n| **MemorySize** | `256` | Memory allocation in MB (128-10,240 MB) |\n| **FunctionName** | `my-lambda-function` | Name of the Lambda function |\n| **Handler** | `index.lambda_handler` | Entry point for function execution |\n| **Role** | ARN | IAM role with Lambda execution permissions |\n\n## Notes:\n- Replace `ACCOUNT_ID` with your actual AWS account ID\n- Adjust `Handler` path based on your code structure\n- Minimum memory is 128 MB; maximum is 10,240 MB\n- Timeout range is 1-900 seconds",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function that specifies the runtime as Python 3.11, timeout of 30 seconds, and memory of 256 MB",
#       "format": "json"
#     },
#     "score": 8,
#     "reasoning": "The solution correctly addresses all core requirements with accurate parameter names, values, and syntax. The documentation is thorough and helpful. However, by including substantial optional configuration without distinguishing it from requirements, the response goes beyond what was asked. A task requesting 'specify runtime, timeout, and memory' could be interpreted as needing only those three fields. The solution would be stronger with a minimal example plus an extended example clearly labeled as optional enhancements."
#   },
#   {
#     "output": "# AWS IAM Role ARN Parser\n\nHere's a Python function that extracts the role name from an AWS IAM role ARN:\n\n```python\ndef extract_role_name_from_arn(arn: str) -> str:\n    \"\"\"\n    Extract the role name from an AWS IAM role ARN.\n    \n    Args:\n        arn (str): The IAM role ARN string in format \n                   'arn:aws:iam::123456789012:role/RoleName'\n    \n    Returns:\n        str: The extracted role name\n    \n    Raises:\n        ValueError: If the ARN format is invalid or doesn't contain a role\n    \n    Example:\n        >>> extract_role_name_from_arn('arn:aws:iam::123456789012:role/MyRole')\n        'MyRole'\n    \"\"\"\n    if not isinstance(arn, str):\n        raise ValueError(\"ARN must be a string\")\n    \n    if not arn.startswith('arn:aws:iam::'):\n        raise ValueError(\"Invalid ARN format. Expected IAM role ARN starting with 'arn:aws:iam::'\")\n    \n    # Split by ':role/' to get the role part\n    parts = arn.split(':role/')\n    \n    if len(parts) != 2:\n        raise ValueError(\"Invalid ARN format. Expected format: 'arn:aws:iam::123456789012:role/RoleName'\")\n    \n    role_name = parts[1]\n    \n    if not role_name:\n        raise ValueError(\"Role name cannot be empty\")\n    \n    return role_name\n\n\n# Test cases\nif __name__ == \"__main__\":\n    # Test 1: Valid ARN\n    arn1 = \"arn:aws:iam::123456789012:role/MyRole\"\n    print(f\"Test 1: {extract_role_name_from_arn(arn1)}\")  # Output: MyRole\n    \n    # Test 2: Role with path\n    arn2 = \"arn:aws:iam::123456789012:role/service/MyRole\"\n    print(f\"Test 2: {extract_role_name_from_arn(arn2)}\")  # Output: service/MyRole\n    \n    # Test 3: Simple role name\n    arn3 = \"arn:aws:iam::987654321098:role/Lambda-Execution-Role\"\n    print(f\"Test 3: {extract_role_name_from_arn(arn3)}\")  # Output: Lambda-Execution-Role\n    \n    # Test 4: Invalid ARN (will raise ValueError)\n    try:\n        invalid_arn = \"arn:aws:iam::123456789012:user/MyUser\"\n        extract_role_name_from_arn(invalid_arn)\n    except ValueError as e:\n        print(f\"Test 4 Error (expected): {e}\")\n```\n\n## Alternative Solutions\n\n### Using Regex (More Flexible)\n```python\nimport re\n\ndef extract_role_name_from_arn_regex(arn: str) -> str:\n    \"\"\"Extract role name using regex pattern.\"\"\"\n    pattern = r'arn:aws:iam::\\d+:role/(.+)$'\n    match = re.match(pattern, arn)\n    \n    if not match:\n        raise ValueError(f\"Invalid IAM role ARN format: {arn}\")\n    \n    return match.group(1)\n\n\n# Test\nprint(extract_role_name_from_arn_regex(\"arn:aws:iam::123456789012:role/MyRole\"))\n```\n\n### Using Simple String Split (Simplest)\n```python\ndef extract_role_name_simple(arn: str) -> str:\n    \"\"\"Simplest version - extract text after last '/'.\"\"\"\n    if ':role/' not in arn:\n        raise ValueError(\"Invalid IAM role ARN format\")\n    \n    return arn.split(':role/')[-1]\n\n\n# Test\nprint(extract_role_name_simple(\"arn:aws:iam::123456789012:",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS IAM role ARN string and returns the role name by extracting it from the ARN format (arn:aws:iam::123456789012:role/RoleName)",
#       "format": "python"
#     },
#     "score": 7,
#     "reasoning": "The solution effectively addresses the core task with robust validation and error handling. The primary implementation is solid and practical. However, there's ambiguity about whether paths should be included in the extracted role name - AWS role ARNs can include paths (arn:aws:iam::123456789012:role/service/MyRole), but the actual 'role name' typically refers only to the final component. The solution treats the entire path+name as the role name, which may not align with AWS API expectations where the role name is just 'MyRole'. The incomplete alternative implementations and missing AWS constraint validation are minor issues. Overall, this is a good, production-ready solution with minor semantic concerns."
#   }
# ]
